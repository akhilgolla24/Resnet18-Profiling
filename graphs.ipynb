# %%
import matplotlib.pyplot as plt

# %%
x = [0, 4, 8, 12, 16]
y = [140.388567, 3.923053, 4.501525, 5.205450, 5.904383]
plt.plot(x, y)  # Plot the chart
plt.xlabel("Num Workers")
plt.ylabel("Total Dataloading Time")
plt.title("Num Workers in Dataloader vs Total Dataloading Time")
plt.show()

# %%
import lab2
model = lab2.Resnet_18(True)
len(list(model.parameters()))
# Out:
# 71

# %%
total_params = 0
total_grad = 0
for ele in model.parameters():
    total_params += ele.numel()
    if ele.requires_grad:
        total_grad += 1

print(total_params)
print(total_grad)
# Out:
# 15648586
# 71
